# %% [markdown]
# ### Buscar trabajos

# %%
#Importamos librerías

import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np

# %%
## direct the webdriver to where the browser file is:

##Chrome
driver = webdriver.Chrome(r'C:\\Users\\fpradell\\Downloads\\chromedriver.exe')

# Credenciales secretas:
email = "elincognito1996@gmail.com"
password = "holamundo123"

# Ir a la página de linkeidIn y loguearse
driver.get('https://www.linkedin.com/login') # Método driver.get navegará a una página dada por la URL
time.sleep(3) # Método time.sleep para hacer que el navegador se detenga durante tres segundos
driver.find_element(By.ID, 'username').send_keys(email) # Método find_element_by_name de Selenium para encontrar las entradas 
                                                        #para la información de inicio de sesión
driver.find_element(By.ID, 'password').send_keys(password)
driver.find_element(By.ID, 'password').send_keys(Keys.RETURN)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# ~\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask)
#     950
# --> 951             self._execute_child(args, executable, preexec_fn, close_fds,
#     952                                 pass_fds, cwd, env,
#
# ~\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1419             try:
# -> 1420                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1421                                          # no special security
#
# FileNotFoundError: [WinError 2] El sistema no puede encontrar el archivo especificado
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25688/64546931.py in <module>
#       2
#       3 ##Chrome
# ----> 4 driver = webdriver.Chrome(r'C:\\Users\\fpradell\\Downloads\\chromedriver.exe')
#       5
#       6 # Credenciales secretas:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
#Buscar trabajos de DS en Argetina
driver.get("https://www.linkedin.com/jobs/")
time.sleep(1)

# find the keywords/location search bars:
search_bars = driver.find_elements(By.CLASS_NAME,'jobs-search-box__text-input')

keywords = 'data scientist'
search_keywords = search_bars[0]
search_keywords.send_keys(keywords)

time.sleep(1)

location = 'Argentina'    
search_location = search_bars[3]
search_location.send_keys(location)

time.sleep(1)

search_location.send_keys(Keys.ENTER)

# %%
# get a list of all the listings elements's in the side bar
list_item = driver.find_elements(By.CLASS_NAME, "occludable-update")

position_list = []
company_list = []
location_list = []
applications_list = []
posted_list = []
details_list = []

# scrolls a single page:
for job in list_item:
    # executes JavaScript to scroll the div into view
    driver.execute_script("arguments[0].scrollIntoView();", job)
    job.click()
    time.sleep(3)
    
    # get info:
    position = job.text.split('\n')[0]
    company = job.text.split('\n')[1]
    location = job.text.split('\n')[2]
    posted_date = driver.find_element(By.CLASS_NAME, "jobs-unified-top-card__posted-date").text    
    details = driver.find_element(By.ID, "job-details").text
    #applications = driver.find_element(By.CLASS_NAME, "jobs-unified-top-card__applicant-count").text    
    
    
    #Appendeo los details a una lista
    position_list.append(position)
    company_list.append(company)
    location_list.append(location)
    #applications_list.append(applications)
    posted_list.append(posted_date)
    details_list.append(details)

# %%
data = pd.DataFrame()
data['Posición'],data['Compañía'],data['Ubicación'], data['Posteado'], data['Detalle'] = [position_list, company_list, location_list, posted_list, details_list]
data
# Out:
#                                       Posición  \
# 0                        Senior Data Scientist
# 1    P&A - Finance | Data Scientist Sr Analyst
# 2                               Data Scientist
# 3   Senior Data Scientist - Argentina Tech Hub
# 4                      Desarrollador de Python
# 5                        Football Statistician
# 6                  Data Scientist - Applied AI
# 7                               DATA SCIENTIST
# 8                               Data Scientist
# 9                               Data Scientist
# 10                              Data Scientist
# 11                               Data Engineer
# 12         Consultor Business Intelligence Jr.
# 13                              Data Scientist
# 14                    Data & Applied Scientist
# 15                              Data Scientist
# 16                              Data Scientist
# 17                              Data Scientist
# 18                      Engineer Data Analysis
# 19                Data Engineer | Remote-LATAM
# 20           Ingeniero senior python fullstack
# 21                                 QA Engineer
# 22                    Data Scientist - Analyst
# 23                      Data Engineer (Remote)
# 24                    Data Engineer (Power BI)
#
#                                Compañía  \
# 0                                Toptal
# 1                   Accenture Argentina
# 2                                GDN AR
# 3                                    Nu
# 4                      GlobalNews Group
# 5                         Genius Sports
# 6                  JPMorgan Chase & Co.
# 7                    Wunderman Thompson
# 8                                 ASAPP
# 9                         Housecall Pro
# 10                            123Seguro
# 11                            OptimHire
# 12       WaveBI - Business Intelligence
# 13                          Kin + Carta
# 14                            Microsoft
# 15         Movistar (Telefónica Hispam)
# 16             Prodigious Latin America
# 17                 Prodigious Worldwide
# 18                               Lenovo
# 19  My own company (I am self-employed)
# 20                       Revelo Network
# 21                           The Colony
# 22                                 Visa
# 23                           Gemography
# 24                           Len & Nyle
#
#                                             Ubicación         Posteado  \
# 0                        Rosario, Santa Fe, Argentina   hace 2 semanas
# 1   Buenos Aires, Provincia de Buenos Aires, Argen...   hace 2 semanas
# 2   Buenos Aires, Provincia de Buenos Aires, Argen...   hace 3 semanas
# 3   Buenos Aires, Provincia de Buenos Aires, Argen...    hace 1 semana
# 4                Provincia de Buenos Aires, Argentina    hace 15 horas
# 5                        Viedma, Río Negro, Argentina     hace 9 horas
# 6   Buenos Aires, Provincia de Buenos Aires, Argen...      hace 4 días
# 7   Buenos Aires, Provincia de Buenos Aires, Argen...    hace 1 semana
# 8                                           Argentina      hace 5 días
# 9             Río Grande, Tierra del Fuego, Argentina   hace 2 semanas
# 10                                          Argentina    hace 1 semana
# 11                                          Argentina  hace 21 minutos
# 12     La Plata, Provincia de Buenos Aires, Argentina     hace 5 horas
# 13  Buenos Aires, Provincia de Buenos Aires, Argen...      hace 5 días
# 14                                          Argentina   hace 2 semanas
# 15               Provincia de Buenos Aires, Argentina      hace 6 días
# 16                                          Argentina   hace 3 semanas
# 17                                          Argentina   hace 3 semanas
# 18  Buenos Aires, Provincia de Buenos Aires, Argen...     hace 3 horas
# 19                                          Argentina       hace 1 día
# 20                                          Argentina      hace 1 hora
# 21                                          Argentina    hace 13 horas
# 22  Buenos Aires, Provincia de Buenos Aires, Argen...    hace 1 semana
# 23                                          Argentina      hace 3 días
# 24                                          Argentina     hace 4 horas
#
#                                               Detalle
# 0   About Toptal\n\nToptal is a global network of ...
# 1   Join Accenture and help transform leading orga...
# 2   Publicado por\nMaría Laura Coria\nHRBP- IT, E-...
# 3   About Nubank\n\nNubank was founded in 2013 to ...
# 4   Publicado por\nDiego Molle\n📣 Marketing | Comu...
# 5   Love sports?\n\nWant to get paid while attendi...
# 6   About Our Team\n\nThe mission of our Applied A...
# 7   Who we are:\n\nAt Wunderman Thompson we exist ...
# 8   At ASAPP, we are on a mission to build transfo...
# 9   Publicado por\nShannon Skalka\nDirector, Talen...
# 10  Publicado por\nSofía Caña\nRecruiter IT en 123...
# 11  Publicado por\nPayal Gupta\nTechnical Recruite...
# 12  En WaveBI, confiamos y creemos que el camino p...
# 13  At Kin + Carta, we’ve got opportunities to off...
# 14  Microsoft Graph and the Microsoft 365 ecosyste...
# 15  Publicado por\nNora Josovich\nTalent acquisiti...
# 16  Publicado por\nANDRES SALCEDO BORRERO\nIT Recr...
# 17  This role will be focus on finding the best au...
# 18  Why Work at Lenovo\nHere at Lenovo, we believe...
# 19  Publicado por\nChandini Chandini\nStudent at T...
# 20  Publicado por\nMelissa Ribeyro Vasquez\nExpert...
# 21  Publicado por\nKaren Kreser\nLic. en Psicologí...
# 22  Company Description\n\nVisa is a world leader ...
# 23  Publicado por\nMeriem MESSAOUDI\nTechnical Rec...
# 24  🚀 To be successful in this role, you have:\n· ...

# %% [markdown]
# ### Buscar perfiles

# %%
#Importamos librerías

import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
## direct the webdriver to where the browser file is:

##Chrome
driver = webdriver.Chrome(r'C:\\Users\\fpradell\\Downloads\\chromedriver.exe')

# Credenciales secretas:
email = "elincognito1996@gmail.com"
password = "holamundo123"

# Ir a la página de linkeidIn y loguearse
driver.get('https://www.linkedin.com/login') # Método driver.get navegará a una página dada por la URL
time.sleep(3) # Método time.sleep para hacer que el navegador se detenga durante tres segundos
driver.find_element(By.ID, 'username').send_keys(email) # Método find_element_by_name de Selenium para encontrar las entradas 
                                                        #para la información de inicio de sesión
driver.find_element(By.ID, 'password').send_keys(password)
driver.find_element(By.ID, 'password').send_keys(Keys.RETURN)

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC


#Buscar perfiles con un apellido en particular 
driver.get("https://www.linkedin.com/")
time.sleep(1)

search = driver.find_element_by_xpath("//input[@aria-label='Buscar']")

keywords = 'Julieta Carricondo Robino' 
search.send_keys(keywords)
search.send_keys(Keys.ENTER)

time.sleep(1)


people_button = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, "[aria-label='Personas']")))
people_button.send_keys(Keys.ENTER)

# %%
# get a list of all the listings elements's in the side bar
list_item = driver.find_elements(By.CLASS_NAME, "reusable-search__result-container ")

name_list = []
cargo_list = []
about_list = []
experiencia_list = []

# scrolls a single page:
for people in list_item:
    # executes JavaScript to scroll the div into view
    driver.execute_script("arguments[0].scrollIntoView();", people)
    time.sleep(1)   
    people.click()
    time.sleep(3)
    
#    # get info:
    name = driver.find_element(By.CSS_SELECTOR, ".pv-text-details__left-panel h1").text
    about = driver.find_element(By.CSS_SELECTOR, ".pv-shared-text-with-see-more .visually-hidden").text
    cargo = driver.find_element(By.XPATH, "//div[@class='text-body-medium break-words']").text
   
    
##    #Appendeo los details a una lista

    name_list.append(name)
    cargo_list.append(cargo)
    about_list.append(about)

# %%
data = pd.DataFrame()
data['Name'], data['Cargo'], data['About'] = [name_list, cargo_list, about_list]
data
# Out:
#                         Name  \
# 0  Julieta Carricondo Robino
#
#                                                Cargo  \
# 0  Data Scientist Lead Analyst en NTT Data Europe...
#
#                                                About
# 0  Soy Julieta Carricondo Robino, bioingeniera. A...
