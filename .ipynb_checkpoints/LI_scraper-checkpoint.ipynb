# %% [markdown]
# ### Buscar trabajos

# %%
#Importamos librerías

import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6572/3906671610.py in <module>
#       1 #Importamos librerías
#       2
# ----> 3 import selenium
#       4 from selenium import webdriver
#       5 import time
#
# ModuleNotFoundError: No module named 'selenium'

# %%
## direct the webdriver to where the browser file is:

##Chrome
driver = webdriver.Chrome(r'C:/Downloads/chromedriver.exe')

# Credenciales secretas:
email = ""
password = ""

# Ir a la página de linkeidIn y loguearse
driver.get('https://www.linkedin.com/login') # Método driver.get navegará a una página dada por la URL
time.sleep(3) # Método time.sleep para hacer que el navegador se detenga durante tres segundos
driver.find_element(By.ID, 'username').send_keys(email) # Método find_element_by_name de Selenium para encontrar las entradas 
                                                        #para la información de inicio de sesión
driver.find_element(By.ID, 'password').send_keys(password)
driver.find_element(By.ID, 'password').send_keys(Keys.RETURN)
# Out:
# C:\Users\vcabodev\AppData\Local\Temp/ipykernel_1692/516669319.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:/Users/vcabodev/Downloads/chromedriver.exe')

# %%
#Buscar trabajos de DS en Argetina
driver.get("https://www.linkedin.com/jobs/")
time.sleep(1)

# find the keywords/location search bars:
search_bars = driver.find_elements(By.CLASS_NAME,'jobs-search-box__text-input')

keywords = 'data scientist'
search_keywords = search_bars[0]
search_keywords.send_keys(keywords)

time.sleep(1)

location = 'Argentina'    
search_location = search_bars[3]
search_location.send_keys(location)

time.sleep(1)

search_location.send_keys(Keys.ENTER)

# %%
# get a list of all the listings elements's in the side bar
list_item = driver.find_elements(By.CLASS_NAME, "occludable-update")

position_list = []
company_list = []
location_list = []
applications_list = []
posted_list = []
details_list = []

# scrolls a single page:
for job in list_item:
    # executes JavaScript to scroll the div into view
    driver.execute_script("arguments[0].scrollIntoView();", job)
    job.click()
    time.sleep(3)
    
    # get info:
    position = job.text.split('\n')[0]
    company = job.text.split('\n')[1]
    location = job.text.split('\n')[2]
    posted_date = driver.find_element(By.CLASS_NAME, "jobs-unified-top-card__posted-date").text    
    details = driver.find_element(By.ID, "job-details").text
    #applications = driver.find_element(By.CLASS_NAME, "jobs-unified-top-card__applicant-count").text    
    
    
    #Appendeo los details a una lista
    position_list.append(position)
    company_list.append(company)
    location_list.append(location)
    #applications_list.append(applications)
    posted_list.append(posted_date)
    details_list.append(details)

# %%
data = pd.DataFrame()
data['Posición'],data['Compañía'],data['Ubicación'], data['Posteado'], data['Detalle'] = [position_list, company_list, location_list, posted_list, details_list]
data
# Out:
#                                       Posición                      Compañía  \
# 0                        Senior Data Scientist                        Toptal
# 1                        Senior Data Scientist                        Toptal
# 2                               Data Scientist                   Kin + Carta
# 3                               Data Scientist                 Housecall Pro
# 4                        Senior Data Scientist                 Wonder Brands
# 5                           Sr Data Scientists   _coderio | Software Company
# 6                               Data Scientist                        GDN AR
# 7                               Data Scientist  Movistar (Telefónica Hispam)
# 8                               Data Scientist                          R/GA
# 9                               Data Scientist                   Avenue Code
# 10                              DATA SCIENTIST            Wunderman Thompson
# 11                              Data Scientist          Prodigious Worldwide
# 12                              Data Scientist      Prodigious Latin America
# 13                    Associate Data Scientist                    Prodigious
# 14                              Data Scientist                    Prodigious
# 15                              Data Scientist                    KUNAN S.A.
# 16   P&A - Finance | Data Scientist Sr Analyst           Accenture Argentina
# 17  Senior Data Scientist - Argentina Tech Hub                        Nubank
# 18                       Senior Data Scientist                        Toptal
# 19                  Data Science & SFE Analyst                        Danone
# 20                  Data Scientist Analyst LAO                Kimberly-Clark
# 21                        Data Scientist Latam                       Equifax
# 22                        Data Scientist Latam                       Equifax
# 23                  Data Scientist Analyst LAO                Kimberly-Clark
# 24                 Data Scientist - Applied AI          JPMorgan Chase & Co.
#
#                                            Ubicación      Posteado  \
# 0                       Rosario, Santa Fe, Argentina   3 weeks ago
# 1                        Cordoba, Córdoba, Argentina   3 weeks ago
# 2     Buenos Aires, Buenos Aires Province, Argentina    6 days ago
# 3   Rio Grande, Tierra del Fuego Province, Argentina   2 weeks ago
# 4                   Buenos Aires Province, Argentina  23 hours ago
# 5                                          Argentina    1 hour ago
# 6     Buenos Aires, Buenos Aires Province, Argentina    6 days ago
# 7                   Buenos Aires Province, Argentina    3 days ago
# 8     Buenos Aires, Buenos Aires Province, Argentina    3 days ago
# 9                                          Argentina   2 weeks ago
# 10    Buenos Aires, Buenos Aires Province, Argentina   2 weeks ago
# 11                                         Argentina     1 day ago
# 12                                         Argentina  23 hours ago
# 13                                         Argentina     1 day ago
# 14                                         Argentina  23 hours ago
# 15                       Cordoba, Córdoba, Argentina     1 day ago
# 16    Buenos Aires, Buenos Aires Province, Argentina   2 weeks ago
# 17    Buenos Aires, Buenos Aires Province, Argentina    1 week ago
# 18    Buenos Aires, Buenos Aires Province, Argentina   6 hours ago
# 19    Buenos Aires, Buenos Aires Province, Argentina     1 day ago
# 20                              Greater Buenos Aires    1 week ago
# 21    Buenos Aires, Buenos Aires Province, Argentina   1 month ago
# 22    Buenos Aires, Buenos Aires Province, Argentina   1 month ago
# 23    Buenos Aires, Buenos Aires Province, Argentina   1 month ago
# 24    Buenos Aires, Buenos Aires Province, Argentina    5 days ago
#
#                                               Detalle
# 0   About Toptal\n\nToptal is a global network of ...
# 1   About Toptal\n\nToptal is a global network of ...
# 2   At Kin + Carta, we’ve got opportunities to off...
# 3   Posted by\nShannon Skalka\nDirector, Talent Ac...
# 4   Posted by\nFlorencia Giordano\nOffice Manager ...
# 5   Posted by\nMary Nicolas 2nd\nhuman Resources\n...
# 6   Posted by\nMaría Laura Coria\nHRBP- IT, E-comm...
# 7   Posted by\nNora Josovich 2nd\nTalent acquisiti...
# 8   We’re looking for Data experts who are excited...
# 9   Posted by\nCaroline Santo\nTalent Acquisition ...
# 10  Who we are:\n\nAt Wunderman Thompson we exist ...
# 11  This role will be focus on finding the best au...
# 12  Posted by\nANDRES SALCEDO BORRERO\nIT Recruite...
# 13  What you’ll do:\n\nWe are offering the amazing...
# 14  This role will be focus on finding the best au...
# 15  We are looking to expand our Artificial Intell...
# 16  Join Accenture and help transform leading orga...
# 17  About Nubank\n\nNubank was founded in 2013 to ...
# 18  About Toptal\n\nToptal is a global network of ...
# 19  About The Job\n\nAl asumir la posición de Data...
# 20  Job Description\n\nIn the Data & Insights Anal...
# 21  Equifax is looking for an experienced Data Sci...
# 22  Equifax is looking for an experienced Data Sci...
# 23  Job Description\n\nIn the Data & Insights Anal...
# 24  About Our Team\n\nThe mission of our Applied A...

# %% [markdown]
# ### Buscar perfiles

# %%
#Importamos librerías

import selenium
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import pandas as pd

# %%
## direct the webdriver to where the browser file is:

##Chrome
driver = webdriver.Chrome(r'C:Downloads/chromedriver.exe')

# Credenciales secretas:
email = ""
password = ""

# Ir a la página de linkeidIn y loguearse
driver.get('https://www.linkedin.com/login') # Método driver.get navegará a una página dada por la URL
time.sleep(3) # Método time.sleep para hacer que el navegador se detenga durante tres segundos
driver.find_element(By.ID, 'username').send_keys(email) # Método find_element_by_name de Selenium para encontrar las entradas 
                                                        #para la información de inicio de sesión
driver.find_element(By.ID, 'password').send_keys(password)
driver.find_element(By.ID, 'password').send_keys(Keys.RETURN)
# Out:
# C:\Users\vcabodev\AppData\Local\Temp/ipykernel_2080/516669319.py:4: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:/Users/vcabodev/Downloads/chromedriver.exe')

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC


#Buscar perfiles con un apellido en particular 
driver.get("https://www.linkedin.com/")
time.sleep(1)

search = driver.find_element(By.XPATH, "//input[@aria-label='Search']")
keywords = 'Julieta Carricondo Robino' 
search.send_keys(keywords)
search.send_keys(Keys.ENTER)

time.sleep(1)


people_button = WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.CSS_SELECTOR, "[aria-label='People']")))
people_button.send_keys(Keys.ENTER)

# %%
# get a list of all the listings elements's in the side bar
list_item = driver.find_elements(By.CLASS_NAME, "reusable-search__result-container ")

name_list = []
cargo_list = []
about_list = []
experiencia_list = []

# scrolls a single page:
for people in list_item:
    # executes JavaScript to scroll the div into view
    driver.execute_script("arguments[0].scrollIntoView();", people)
    time.sleep(1)   
    people.click()
    time.sleep(3)
    
#    # get info:
    name = driver.find_element(By.CSS_SELECTOR, ".pv-text-details__left-panel h1").text
    about = driver.find_element(By.CSS_SELECTOR, ".pv-shared-text-with-see-more .visually-hidden").text
    cargo = driver.find_element(By.XPATH, "//div[@class='text-body-medium break-words']").text
   
    
##    #Appendeo los details a una lista

    name_list.append(name)
    cargo_list.append(cargo)
    about_list.append(about)

# %%
data = pd.DataFrame()
data['Name'], data['Cargo'], data['About'] = [name_list, cargo_list, about_list]
data
# Out:
#                         Name                          Cargo  \
# 0  Julieta Carricondo Robino  Data Scientist / Scrum Master
#
#                                                About
# 0  Soy Julieta Carricondo Robino, bioingeniera. A...
